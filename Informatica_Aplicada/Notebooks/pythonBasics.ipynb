# %% [markdown]
# https://automatetheboringstuff.com/

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
2 + 3 * 6

# %%
2 ** 8

# %%
23 / 7

# %%
23 % 7

# %%
(5 - 1) * ((7 + 1) / (3 - 1))

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
'Alice' + 'Bob'

# %%
'Alice' + 42

# %%
'Alice' * 5

# %%
'Alice' * 5.0

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
spam = 40

# %%
eggs = 2

# %%
spam + eggs

# %%
spam + eggs + spam

# %%
spam = spam + 2

# %%
spam = 'Hello'

# %%
spam = input()

# %%
spam = input()

# %%
spam
# Out:
# '101'

# %%
spam = int(spam)

# %%
int(7.7) + 1

# %%
bacon = 20
bacon + 1

# %%
bacon

# %% [markdown]
# Variable names are case-sensitive, meaning that spam, SPAM, Spam, and sPaM are four different variables. Though Spam is a valid variable you can use in a program, it is a Python convention to start your variables with a lowercase letter.
#
# I suggest the use camelcase for variable names instead of underscores; that is, variables lookLikeThis instead of looking_like_this.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# This program says hello and asks for my name.
print('Hello, world!')
print('What is your name?')    # ask for their name
# Out:
# Hello, world!
# What is your name?

# %%
myName = input()

# %%
print('It is good to meet you, ' + myName)
print('The length of your name is:')
print(len(myName))
# Out:
# It is good to meet you, robson
# The length of your name is:
# 6

# %%
print('What is your age?')    # ask for their age
myAge = input()
print('You will be ' + str(int(myAge) + 1) + ' in a year.')
# Out:
# What is your age?
# You will be 51 in a year.
